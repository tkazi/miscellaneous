# %%
import numpy as np
import pandas as pd
import seaborn as sns

from __future__ import division
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import sklearn.preprocessing as skpp
from pandas.tools.plotting import scatter_matrix

# %matplotlib inline
sns.set_style('whitegrid')

# %%
df = pd.read_csv('/Users/Taha/Desktop/datascience/notebooks/edmodo/districts_teachers_28d.csv')

#df = df.sort_values(by='date', ascending=True)
df = df.set_index('date')
df.head()
# Out:
#          id  year  month  actives
# date
# 6/1/13  1.0  2013      6        6
# 6/1/13  4.0  2013      6        4
# 6/1/13  6.0  2013      6       22
# 6/1/13  7.0  2013      6        6
# 6/1/13  8.0  2013      6        3

# %%
d_id = 11471
df_chart = df[df['id'] == d_id]
df_chart['actives'].plot(x='actives',y='date', figsize=(15,4))

plt.suptitle('28d Actives - Cumberland County', fontsize=16)
plt.ylabel('28d actives', fontsize=12)
plt.ylim([0,4200])
# Out:
# (0, 4200)

# %%
d_id = 5091
df_chart = df[df['id'] == d_id]
df_chart['actives'].plot(x='actives',y='date', figsize=(15,4))

plt.suptitle('28d Actives - Blue Valley School District', fontsize=16)
plt.ylabel('28d actives', fontsize=12)
plt.ylim([0,1200])
# Out:
# (0, 1200)

# %%
d_id = 11566
df_chart = df[df['id'] == d_id]
df_chart['actives'].plot(x='actives',y='date', figsize=(15,4))

plt.suptitle('28d Actives - Onslow County District', fontsize=16)
plt.ylabel('28d actives', fontsize=12)
#plt.ylim([0,1200])

# %%
d_id = 1426
df_chart = df[df['id'] == d_id]
df_chart['actives'].plot(x='actives',y='date', figsize=(15,4))

plt.suptitle('28d Actives - Encinitas Union Elementary', fontsize=16)
plt.ylabel('28d actives', fontsize=12)
#plt.ylim([0,1200])

# %%
d_id = 4485
df_chart = df[df['id'] == d_id]
df_chart['actives'].plot(x='actives',y='date', figsize=(15,4))

plt.suptitle('28d Actives - Logansport Community', fontsize=16)
plt.ylabel('28d actives', fontsize=12)

#plt.ylim([0,4200])

# %%
d_id = 11234
df_chart = df[df['id'] == d_id]
df_chart['actives'].plot(x='actives',y='date', figsize=(15,4))

plt.suptitle('28d Actives - Saratoga Springs District', fontsize=16)
plt.ylabel('28d actives', fontsize=12)

#plt.ylim([0,4200])
