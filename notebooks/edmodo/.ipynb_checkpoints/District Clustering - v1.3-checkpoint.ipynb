# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_style('whitegrid')
import plotly.plotly as py
from plotly.graph_objs import *

from __future__ import division
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import sklearn.preprocessing as skpp
from pandas.tools.plotting import scatter_matrix

# %%
df_t = pd.read_csv('/Users/Taha/Downloads/cluster-districts.csv')

# %%
df_t.count()
# Out:
# date             2706685
# month            2706685
# id               2706685
# name             2706685
# state            2706685
# county           2702767
# 7d               2706685
# 28d              2706685
# schools          2706685
# max_7d           2706685
# registered       2706685
# nces_teachers    2706685
# dtype: int64

# %%
df_original = df_t.groupby(['id'],as_index=False)

# %%
df_original = df_t.groupby(['id'],as_index=False).agg({'name':'count'})

# %%
df_original.count()
# Out:
# id      4145
# name    4145
# dtype: int64

# %%
df = pd.read_csv('/Users/Taha/Desktop/datascience/notebooks/edmodo')

# -----------------------

df = df.set_index('date')
df['date'] = df.index

# -----------------------

def get_period(date):
    if ( date[0:4] == '2014'and date[5:7] in ('08','09','10','11','12') ) or ( date[0:4]=='2015'and date[5:7] in ('01',
                                                                                                '02','03','04','05') ):
        return '14-15'
    if ( date[0:4] == '2015'and date[5:7] in ('08','09','10','11','12') ) or ( date[0:4]=='2016'and date[5:7] in ('01',
                                                                                            '02','03','04','05') ):
        return '15-16'
    if ( date[0:4] == '2015'and date[5:7] in ('06','07') ):
        return 'summer 14-15'
    else:
        return 'no period'
    
df['period'] = df['date'].apply(get_period)

# -----------------------

df = df[ df['date'] > '2014-07-31' ]
df = df[df['nces_teachers'] >= 100]
#df = df[df['28d'] > 5]

# -----------------------

df_14_15 = df[ df['period'] == '14-15']
df_15_16 = df[ df['period'] == '15-16']
df_s_14_15 = df[ df['period'] == 'summer 14-15']

# -----------------------

df_14_15_g = df_14_15.groupby(['id'],as_index=False).agg({'28d':['mean','std'],'nces_teachers':'max', 'name':'max'})
df_15_16_g = df_15_16.groupby(['id'],as_index=False).agg({'28d':['mean','std'], 'nces_teachers':'max', 'name':'max'})
df_s_14_15_g = df_s_14_15.groupby(['id'],as_index=False).agg({'28d':['mean','std'],'nces_teachers':'max', 'name':'max'})

# -----------------------

df_14_15_g['mean'] = df_14_15_g['28d']['mean']
df_14_15_g['std']  = df_14_15_g['28d']['std']

df_15_16_g['mean'] = df_15_16_g['28d']['mean']
df_15_16_g['std']  = df_15_16_g['28d']['std']

df_s_14_15_g['mean'] = df_s_14_15_g['28d']['mean']
df_s_14_15_g['std']  = df_s_14_15_g['28d']['std']

# -----------------------

df_14_15_g = df_14_15_g.drop('28d', 1)
df_14_15_g.columns = df_14_15_g.columns.droplevel(1)

df_15_16_g = df_15_16_g.drop('28d', 1)
df_15_16_g.columns = df_15_16_g.columns.droplevel(1)

df_s_14_15_g = df_s_14_15_g.drop('28d', 1)
df_s_14_15_g.columns = df_s_14_15_g.columns.droplevel(1)

# -----------------------

df_graph = pd.merge(df_14_15_g[['id','mean','name','nces_teachers']], df_15_16_g[['id', 'mean','name','nces_teachers']], on='id')
df_graph = df_graph.drop(['name_y','nces_teachers_y'],1)
df_graph = df_graph.rename(columns={'mean_x':'28d_14_15', 'mean_y':'28d_15_16','name_x':'name','nces_teachers_x':'teachers'})
df_graph.head()

# -----------------------

df_graph['diff'] = df_graph['28d_15_16'] - df_graph['28d_14_15']

# -----------------------

df_graph['pen_28d_14_15'] = df_graph['28d_14_15'] / df_graph['teachers']
df_graph['pen_28d_15_16'] = df_graph['28d_15_16'] / df_graph['teachers']

# -----------------------

df_graph['loss_or_gain'] = df_graph['diff'] / df_graph['teachers']
df_graph.head()

# -----------------------

fig, ax = plt.subplots()

ax.plot(df_graph.loss_or_gain, df_graph.pen_28d_15_16, marker='o', linestyle='', ms=6)

ax.set_xlabel("loss or gain from 2014 - 2015")
ax.set_ylabel("28d district penetration 2015 - 2016")

ax.set_xlim([-0.75,0.75])
ax.set_ylim([0,1])

# #best fit line
# ax.plot(df_graph.pen_7d_14_15, 
#         np.poly1d(np.polyfit(df_graph.pen_7d_14_15, df_graph.pen_7d_15_16, 1))(df_graph.pen_7d_14_15),
#          lw=0.025, linestyle='--', color='red')

# # if means from both years are the same, then linear line
# x_ideal = [0,0.2,0.4,0.6,0.8,0.85]
# y_ideal = [0,0.2,0.4,0.6,0.8,0.85]
# ax.plot(x_ideal, y_ideal, lw=0.05)

fig.set_size_inches(22, 12)
plt.show()

# -----------------------
# Out:
# /Users/Taha/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:55: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#
# /Users/Taha/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:58: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#
# /Users/Taha/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:61: PerformanceWarning:
#
# dropping on a non-lexsorted multi-index without a level parameter may impact performance.

# %%
df_graph.count()
# Out:
# id               3861
# 28d_14_15        3861
# name             3861
# teachers         3861
# 28d_15_16        3861
# diff             3861
# pen_28d_14_15    3861
# pen_28d_15_16    3861
# loss_or_gain     3861
# dtype: int64

# %%
# trace0 = Scatter(x=df_graph.loss_or_gain, y=df_graph.pen_28d_15_16,mode='markers',text=df_graph.id,
#                  marker=Marker(
#         color='rgb(63,110,160)',
#         size=12,
#         line=Line(
#             color='#fff',
#             width=0.25
#         )
#     ))

# data = Data([trace0])
# layout = Layout(
#     title='',
#     yaxis=YAxis(
#         title=''
#     )
# )
# fig = Figure(data=data, layout=layout)
# py.iplot(fig)

# %%
#df_graph.to_csv('district_loss_or_grain.csv')

# %%
# df_graph = df_graph[df_graph['loss_or_gain'] > - 1]

# def get_label(teachers):
#     if teachers > 5000:
#         return 20
#     if teachers > 1000 and teachers <= 5000:
#         return 12
#     if teachers > 500 and teachers <= 1000:
#         return 8
#     if teachers > 250 and teachers <= 500:
#         return 4
#     if teachers > 100 and teachers <= 250:
#         return 2

# df_graph['tier'] = df_graph['teachers'].apply(get_label)

# %%
# import plotly.plotly as py
# import plotly.graph_objs as go


# trace0 = go.Scatter(
#     x=df_graph.loss_or_gain,
#     y=df_graph.pen_28d_15_16,
#     mode='markers',
#     marker=dict(
#         #color=['rgb(93, 164, 214)', 'rgb(255, 144, 14)','rgb(44, 160, 101)', 'rgb(255, 65, 54)','rgb(255, 165, 24)'],
#         color = ['red','green','blue','purple','red'],
#         size=df_graph.tier
#     )
# )
# data = [trace0]
# layout = go.Layout(
#     yaxis=dict(
#         autotick=False,
#         ticks='',
#         tick0=0,
#         dtick=0.05,
#         ticklen=20,
#         tickwidth=2,
#         tickcolor='#000',
#         range=[-.1, 1]
#     ),
#     xaxis=dict(
#         autotick=False,
#         ticks='',
#         tick0=0,
#         dtick=0.05,
#         ticklen=12,
#         tickwidth=1,
#         tickcolor='#000',
#         range=[-0.55, 0.55]
#     ),
#     showlegend=True,
#     height=1500,
#     width=1000,
# )
# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig)

# %%
# import plotly.plotly as py
# import plotly.graph_objs as go


# trace0 = go.Scatter(
#     x=df_graph.loss_or_gain,
#     y=df_graph.pen_28d_15_16,
#     mode='markers',
#     marker=dict(
#         #color=['rgb(93, 164, 214)', 'rgb(255, 144, 14)','rgb(44, 160, 101)', 'rgb(255, 65, 54)','rgb(255, 165, 24)'],
#         color = ['red','green','blue','purple','black'],
#         size=df_graph.tier
#     )
# )
# data = [trace0]
# layout = go.Layout(
#     yaxis=dict(
#         autotick=False,
#         ticks='',
#         tick0=0,
#         dtick=0.05,
#         ticklen=20,
#         tickwidth=2,
#         tickcolor='#000',
#         range=[-.1, .5]
#     ),
#     xaxis=dict(
#         autotick=False,
#         ticks='',
#         tick0=0,
#         dtick=0.05,
#         ticklen=12,
#         tickwidth=1,
#         tickcolor='#000',
#         range=[-0.25, 0.25]
#     ),
#     showlegend=True,
#     height=1500,
#     width=1000,
# )
# fig = go.Figure(data=data, layout=layout)
# py.iplot(fig)

# %%
def get_delta_q(df_graph):
    if df_graph['loss_or_gain'] > 0 and df_graph['pen_28d_15_16'] >= 0.3:
        return 'q1'
    if df_graph['loss_or_gain'] > 0 and df_graph['pen_28d_15_16'] < 0.3:
        return 'q4'
    if df_graph['loss_or_gain'] < 0 and df_graph['pen_28d_15_16'] >= 0.3:
        return 'q2'
    if df_graph['loss_or_gain'] < 0 and df_graph['pen_28d_15_16'] < 0.3:
        return 'q3'

df_graph['quadrant']= df_graph.apply(get_delta_q, axis=1)

# %%
df_graph[['id','name',
          'teachers',
          '28d_14_15',
          '28d_15_16',
          'loss_or_gain',
          'pen_28d_15_16']].loc[df_graph['quadrant'] == 'q3' ].sort_values(by='loss_or_gain',ascending=True)
# Out:
#          id                                      name  teachers    28d_14_15  \
# 1176   8046                Pascagoula School District       517   601.940789
# 842    5420                                  Boyle Co       171   113.884868
# 1977  15625                                Keller ISD      1941  1352.743421
# 1551  11601                   Scotland County Schools       469   343.444079
# 1744  14616                               Anderson 01       514   331.217105
# 1768  14667                      Horry County Schools      2638  1696.154605
# 1908  15251                           Clear Creek ISD      2453  1094.598684
# 1381  10729  East Irondequoit Central School District       274   107.960526
# 1572  11981                Bowling Green City Schools       157    64.476974
# 70      142                          Talladega County       591   288.848684
# 289    1675                      Los Altos Elementary       206    76.470395
# 36       77                            Hartselle City       239    79.394737
# 1147   7339                   Western School District       146    53.473684
# 194    1278                 Campbell Union Elementary       339   129.411184
# 42       86                               Jasper City       215   119.697368
# 649    3063             Richmond County School System      2074   929.789474
# 343    1868            Palos Verdes Peninsula Unified       463   254.355263
# 1790  14701                            Spartanburg 05       517   153.042763
# 1109   7081           Mt. Morris Consolidated Schools       121    39.322368
# 602    2955               Coweta County School System      1422   517.815789
# 1766  14661                              Greenwood 50       500   144.167763
# 635    3018                                Lee County       368   104.677632
# 1988  15675                             Lancaster Isd       343   138.621711
# 192    1265             Cajon Valley Union Elementary       671   194.832237
# 396    2057                            High Tech High       107    42.907895
# 1154   7546       Grand Rapids Public School District       213    54.764706
# 532    2835                                   Calhoun       177    46.150000
# 735    3892           Morton Unit School District 709       237    73.667763
# 885    5524                              Meade County       291    88.759868
# 38       81                               Hoover City      1052   306.496711
# ...     ...                                       ...       ...          ...
# 1235   9373                      Omaha Public Schools      3103     8.446429
# 1580  12168                            Fairfield City       485     6.916667
# 748    4092                   Rock Island-Milan SD 41       565    13.483553
# 159    1145                  Adelanto School District       316    13.427632
# 2066  16208                                United Isd      2514    10.403614
# 999    6168                                Fall River       735     6.450704
# 1554  11624               Transylvania County Schools       268    10.261905
# 1979  15645                                 Klein Isd      2998    12.147541
# 149    1069                Pine Bluff School District       342     7.814815
# 190    1257                         Burton Elementary       174     6.096774
# 1639  13489                                     Union       812    17.858553
# 7        19                               Bibb County       233    15.828947
# 2177  17224         Quillayute Valley School District       131     6.469136
# 399    2085                      Sierra Sands Unified       221     6.531250
# 1863  15026            Tullahoma City School District       242     7.369231
# 1855  15008              Robertson County School Dist       777    13.620438
# 1201   8354          Lee's Summit R-7 School District      1105     8.537815
# 721    3672                         Hinsdale Ccsd 181       419     8.541436
# 2049  16093                               Sherman ISD       499     6.382353
# 292    1692                           Lynwood Unified       570    10.355932
# 743    4003                             Pekin Psd 108       292     7.240642
# 1424  11052     New York City Geographic District #12      1688     6.574803
# 665    3127                         Caldwell District       366    11.912587
# 342    1866                        Palo Verde Unified       139     7.119048
# 1118   7185             Redford Union School District       171     6.230769
# 2176  17221                  Puyallup School District      1028     6.101695
# 1446  11109         Nyc Special Schools - District 75      4671     7.176471
# 1354  10471               Gadsden Independent Schools       916    24.197368
# 341    1865                         Palo Alto Unified       678     7.500000
# 751    4113                         Sandwich CUSD 430       241    11.615385
#
#        28d_15_16  loss_or_gain  pen_28d_15_16
# 1176   66.214575     -1.036221       0.128075
# 842    18.028340     -0.560564       0.105429
# 1977  411.587045     -0.484882       0.212049
# 1551  121.461538     -0.473310       0.258980
# 1744  109.570850     -0.431218       0.213173
# 1768  705.862348     -0.375395       0.267575
# 1908  175.473684     -0.374694       0.071534
# 1381   10.785714     -0.354653       0.039364
# 1572    9.329949     -0.351255       0.059426
# 70     97.854251     -0.323172       0.165574
# 289    10.882591     -0.318387       0.052828
# 36      9.209091     -0.293664       0.038532
# 1147   10.694915     -0.293005       0.073253
# 194    31.425101     -0.289044       0.092699
# 42     57.732794     -0.288207       0.268525
# 649   378.408907     -0.265854       0.182454
# 343   132.639676     -0.262885       0.286479
# 1790   19.319838     -0.258652       0.037369
# 1109    8.174863     -0.257417       0.067561
# 602   159.684211     -0.251851       0.112296
# 1766   19.935223     -0.248465       0.039870
# 635    13.705628     -0.247207       0.037244
# 1988   56.032389     -0.240785       0.163360
# 192    35.574899     -0.237343       0.053018
# 396    17.672065     -0.235849       0.165159
# 1154    6.250000     -0.227769       0.029343
# 532     6.000000     -0.226836       0.033898
# 735    21.295547     -0.220980       0.089855
# 885    25.085020     -0.218814       0.086203
# 38     78.898785     -0.216348       0.074999
# ...          ...           ...            ...
# 1235    6.000000     -0.000788       0.001934
# 1580    6.575342     -0.000704       0.013557
# 748    13.102881     -0.000674       0.023191
# 159    13.215447     -0.000671       0.041821
# 2066    8.849398     -0.000618       0.003520
# 999     6.000000     -0.000613       0.008163
# 1554   10.101449     -0.000599       0.037692
# 1979   10.354430     -0.000598       0.003454
# 149     7.622642     -0.000562       0.022288
# 190     6.000000     -0.000556       0.034483
# 1639   17.408907     -0.000554       0.021440
# 7      15.704453     -0.000534       0.067401
# 2177    6.400000     -0.000528       0.048855
# 399     6.416667     -0.000518       0.029035
# 1863    7.250000     -0.000493       0.029959
# 1855   13.247826     -0.000480       0.017050
# 1201    8.067568     -0.000426       0.007301
# 721     8.382353     -0.000380       0.020006
# 2049    6.196078     -0.000373       0.012417
# 292    10.178571     -0.000311       0.017857
# 743     7.178571     -0.000213       0.024584
# 1424    6.226667     -0.000206       0.003689
# 665    11.837104     -0.000206       0.032342
# 342     7.090909     -0.000202       0.051014
# 1118    6.212121     -0.000109       0.036328
# 2176    6.000000     -0.000099       0.005837
# 1446    6.833333     -0.000073       0.001463
# 1354   24.149798     -0.000052       0.026364
# 341     7.486111     -0.000020       0.011041
# 751    11.611111     -0.000018       0.048179
#
# [2048 rows x 7 columns]

# %%
df_graph.head()
# Out:
#    id  28d_14_15              name  teachers  28d_15_16       diff  \
# 0   6  30.598684  Albertville City       273  10.830688 -19.767996
# 1   9  27.190789     Anniston City       138  20.639676  -6.551113
# 2  11  11.294702       Athens City       209   7.540000  -3.754702
# 3  13  13.782895       Auburn City       478   6.645833  -7.137061
# 4  14  30.256579    Autauga County       606  15.943320 -14.313259
#
#    pen_28d_14_15  pen_28d_15_16  loss_or_gain quadrant
# 0       0.112083       0.039673     -0.072410       q3
# 1       0.197035       0.149563     -0.047472       q3
# 2       0.054042       0.036077     -0.017965       q3
# 3       0.028835       0.013903     -0.014931       q3
# 4       0.049928       0.026309     -0.023619       q3

# %%
df_graph.to_csv('district_quadrants.csv')

# %%
amb = [14216,11781,3919,5629,15637,10824,15192,16865,5707,2878,2902,15010,18551,17986,6006,2887,16819,6018,3817,9471,17977,14693,11578,1748,7315,14630,2336,2834,2270,14927,2545,10874,1487,11493,6002,17517,14667,15260,11413,3050,410,20375,2320,15595,18081,398,4737,15098,1276,11299,11234,2895,11172,1699,15786,11430,15489,7651,5648,66,2872,7187,3072,18583,5299,10579,10326,11112,2987,11589,5494,2658,355,14851,14652,1323,8416,10413,3763,87,2975,2290,14660,2985,14598,16344,5630,17988,2840,16863,2929,15251,15516,14632,10362,540,10213,12956,10322,2946,11070,3111,11592,2980,2885,16993,16124,13610,18082,202,10896,2843,15514,19752,3461,16953,2949,7810,1561,4871,16302,19309,13345,3004,2849,15420,15183,11566,2050,13118,181,5091,2883,11109,12750,14863,5604,665,11332,18377,19903,6745,17359,2600,2934,18944,6749,503,6550,11081,1785,2110,3053,14948,17709,5424,11050,18012,15895,6003,2174,3234,1452,10017,4359,15704,2938,15777,83,11579,10384,18269,5617,11432,19187,16880,775,11635,3550,3480,15490,4293,3799,2833,15691,8655,17231,2994,15089,817,14354,11144,8365,4684,5395,1160,11507,8513,15625,15788,4514,5478,10706,1062,3431,15976,14648,17669,2963,14973,1105,10241,16052,1729,11326,11069,9945,6381,11471,2957,2374,12944,17007,10354,15381,14952,10226,3710,8325,16110,14641,14395,19422,20956]

df_amb = df_graph[df_graph['id'].isin(amb)]

# %%
fig, ax = plt.subplots()


ax.set_xlabel("loss or gain from 2014 - 2015")
ax.set_ylabel("28d district penetration 2015 - 2016")

ax.set_xlim([-0.75,0.75])
ax.set_ylim([0,1])

ax.plot(df_graph.loss_or_gain, df_graph.pen_28d_15_16, marker='o', linestyle='', ms=6)
ax.plot(df_amb.loss_or_gain, df_amb.pen_28d_15_16, marker='o', linestyle='', ms=6, color='purple')


fig.set_size_inches(22, 12)
plt.show()

# %%
df_graph.head()
# Out:
#    id  28d_14_15              name  teachers  28d_15_16       diff  \
# 0   6  30.598684  Albertville City       273  10.830688 -19.767996
# 1   9  27.190789     Anniston City       138  20.639676  -6.551113
# 2  11  11.294702       Athens City       209   7.540000  -3.754702
# 3  13  13.782895       Auburn City       478   6.645833  -7.137061
# 4  14  30.256579    Autauga County       606  15.943320 -14.313259
#
#    pen_28d_14_15  pen_28d_15_16  loss_or_gain quadrant
# 0       0.112083       0.039673     -0.072410       q3
# 1       0.197035       0.149563     -0.047472       q3
# 2       0.054042       0.036077     -0.017965       q3
# 3       0.028835       0.013903     -0.014931       q3
# 4       0.049928       0.026309     -0.023619       q3

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

# Generate fake data
x = df_graph['loss_or_gain']
y = df_graph['pen_28d_15_16']

# Calculate the point density
xy = np.vstack([x,y])
z = gaussian_kde(xy)(xy)

# Sort the points by density, so that the densest points are plotted last
idx = z.argsort()
x, y, z = x[idx], y[idx], z[idx]

fig, ax = plt.subplots()
ax.scatter(x, y, c=z, s=50, edgecolor='')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

a = df_graph['loss_or_gain']
b = df_graph['pen_28d_15_16']

plt.hist2d(a, b, (500,500), cmap=plt.cm.jet)
plt.xlim([-0.2, 0.2])
plt.ylim([0,0.2])
plt.colorbar()
